# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
user = '*******'
password = '*******'
server = '************'
db = 'sistema'
engine_destino = create_engine('mssql+pyodbc://'+user+':'+password+'@'+server+'/'+db+'?Driver={SQL SERVER}')
# Out:
# C:\Users\Maykon\AppData\Local\Temp/ipykernel_8316/4163926374.py:5: SAWarning: No driver name specified; this is expected by PyODBC when using DSN-less connections
#   engine_destino = create_engine('mssql+pyodbc://'+user+':'+password+'@'+server+'/'+db+'?Driver={SQL SERVER}')

# %%
user = '******'
password = '******'
server = '**********'
db = 'AdventureWorks2019'
engine_origem = create_engine('mssql+pyodbc://'+user+':'+password+'@'+server+'/'+db+'?Driver={SQL SERVER}')
# Out:
# C:\Users\Maykon\AppData\Local\Temp/ipykernel_8316/3455220355.py:5: SAWarning: No driver name specified; this is expected by PyODBC when using DSN-less connections
#   engine_origem = create_engine('mssql+pyodbc://'+user+':'+password+'@'+server+'/'+db+'?Driver={SQL SERVER}')

# %%
sql = "select * from Production.Product"

# %%
df_pproduct = pd.read_sql(sql,con = engine_origem)

# %%
df_pproduct.to_sql('PRODUCTION.PRODUCT', con=engine_destino, index=False, if_exists='replace')

# %%
df_pproduct
# Out:
#      ProductID                   Name ProductNumber  MakeFlag  \
# 0            1        Adjustable Race       AR-5381     False
# 1            2           Bearing Ball       BA-8327     False
# 2            3        BB Ball Bearing       BE-2349      True
# 3            4  Headset Ball Bearings       BE-2908     False
# 4          316                  Blade       BL-2036      True
# ..         ...                    ...           ...       ...
# 499        995      ML Bottom Bracket       BB-8107      True
# 500        996      HL Bottom Bracket       BB-9108      True
# 501        997     Road-750 Black, 44    BK-R19B-44      True
# 502        998     Road-750 Black, 48    BK-R19B-48      True
# 503        999     Road-750 Black, 52    BK-R19B-52      True
#
#      FinishedGoodsFlag  Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0                False   None              1000           750        0.0000
# ...
